# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import dotenv
import sqlalchemy
import pandas as pd
from sqlalchemy import create_engine
dotenv.load_dotenv(override=True, dotenv_path="C:/Users/Giuseppe/OneDrive/Desktop/DATA ANALYST/3_PYTHON/.env")
username = os.getenv("username")
password = os.getenv("password")
host = os.getenv("host")
dbname = os.getenv("dbname")
conn_string = "mysql+pymysql://" + username + ":" + password + "@" + host + "/" + dbname
db_engine = sqlalchemy.create_engine(conn_string)
conn_string
# Out:
# 'mysql+pymysql://studente_dapt:Ep1c0d3!!D4t4**4n4lys1s@epicode-data-pt-mysql.cvetyjye2qbl.eu-central-1.rds.amazonaws.com/AdventureWorksDW'

# %%
query = "SELECT * FROM dimproduct"
pd.read_sql(query, db_engine)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                    None                None        Adjustable Race
# 1                    None                None           Bearing Ball
# ...

# %%
#Esercizio 1/3 Estraioamo la Tabella dimproduct... e valutiamo quanto segue :  #
#•Quanti dati ci sono in totale?
#• Quali sono i metadati?
#• Stampiamo il primo elemento
#• Stampiamo l'ultimo elemento
#• Riusciamo a stampare cinque elementi a caso?
#• Quali sono i colori disponibili?#

# %%
import pandas as pd  #Importo la libreria Pandas#

# %%
df = pd.read_sql(query, db_engine) #metto in una variabile la mia query della tabella dimproduct#

# %%
df.shape #Utilizzo l'attributo shape per conoscere numero di righe e colonne#
# Out:
# (606, 36)

# %%
list (df.columns) # utilizzo l'attirbuto columns facendomi restituire della tabella solo intestazione colonna in una lista#
# Out:
# ['ProductKey',
#  'ProductAlternateKey',
#  'ProductSubcategoryKey',
#  'WeightUnitMeasureCode',
#  'SizeUnitMeasureCode',
#  'EnglishProductName',
#  'SpanishProductName',
#  'FrenchProductName',
#  'StandardCost',
#  'FinishedGoodsFlag',
#  'Color',
#  'SafetyStockLevel',
#  'ReorderPoint',
#  'ListPrice',
#  'Size',
#  'SizeRange',
#  'Weight',
#  'DaysToManufacture',
#  'ProductLine',
#  'DealerPrice',
#  'Class',
#  'Style',
#  'ModelName',
#  'LargePhoto',
#  'EnglishDescription',
#  'FrenchDescription',
#  'ChineseDescription',
#  'ArabicDescription',
#  'HebrewDescription',
#  'ThaiDescription',
#  'GermanDescription',
#  'JapaneseDescription',
#  'TurkishDescription',
#  'StartDate',
#  'EndDate',
#  'Status']

# %%
df.columns # lo stesso lo potevo ottenere ... ma non in formato lista... utilizzando semplicemetne .columns#
# Out:
# Index(['ProductKey', 'ProductAlternateKey', 'ProductSubcategoryKey',
#        'WeightUnitMeasureCode', 'SizeUnitMeasureCode', 'EnglishProductName',
#        'SpanishProductName', 'FrenchProductName', 'StandardCost',
#        'FinishedGoodsFlag', 'Color', 'SafetyStockLevel', 'ReorderPoint',
#        'ListPrice', 'Size', 'SizeRange', 'Weight', 'DaysToManufacture',
#        'ProductLine', 'DealerPrice', 'Class', 'Style', 'ModelName',
#        'LargePhoto', 'EnglishDescription', 'FrenchDescription',
#        'ChineseDescription', 'ArabicDescription', 'HebrewDescription',
#        'ThaiDescription', 'GermanDescription', 'JapaneseDescription',
#        'TurkishDescription', 'StartDate', 'EndDate', 'Status'],
#       dtype='object')

# %%
df.head(1) #Per stampare il 1° elemento utilizzo la f(x) head... indicando la 1° riga#
# Out:
#    ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0           1             AR-5381                    NaN
#
#   WeightUnitMeasureCode SizeUnitMeasureCode EnglishProductName  \
# 0                  None                None    Adjustable Race
#
#   SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  ...  \
# 0                                                NaN                  0  ...
#
#   ChineseDescription  ArabicDescription  HebrewDescription  ThaiDescription  \
# 0               None               None               None             None
#
#   GermanDescription JapaneseDescription  TurkishDescription  StartDate  \
# 0              None                None                None 2003-07-01
#
#   EndDate   Status
# 0     NaT  Current
#
# [1 rows x 36 columns]

# %%
df.tail(1) #Per stampare l'ultima colonna utilizzo la f(x) tail ... attnenziona a non far confusione tra productkey#
# e etichetta tabella che partendo da 0 è 605 ... mentre ProductKey è 606 #
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode  EnglishProductName  \
# 605                    LB                  CM  Road-750 Black, 52
#
#             SpanishProductName           FrenchProductName  StandardCost  \
# 605  Carretera: 750, negra, 52  Vélo de route 750 noir, 52        343.65
#
#      FinishedGoodsFlag  ...                 ChineseDescription  \
# 605                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
#
#                                      ArabicDescription  \
# 605  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
#
#                                      HebrewDescription  \
# 605  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
#
#                                        ThaiDescription  \
# 605  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
#
#                                      GermanDescription  \
# ...

# %%
df.sample(5) #con la f(x) sample mi restituisce un numero n di righe casuali #
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 452         453           SH-M897-M                   22.0
# 327         328          BK-R50R-48                    2.0
# 129         130             LN-5162                    NaN
# 56           57             HN-1220                    NaN
# 467         468           GL-F110-S                   20.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode      EnglishProductName  \
# 452                  None                None  Men's Sports Shorts, M
# 327                    LB                  CM        Road-650 Red, 48
# 129                  None                None             Lock Nut 11
# 56                   None                None              Hex Nut 17
# 467                  None                None   Full-Finger Gloves, S
#
#                               SpanishProductName  \
# 452  Pantalones cortos de deporte para hombre, M
# 327                     Carretera: 650, roja, 48
# 129
# 56
# ...

# %%
df['Color'].unique() #Indico la colonna che mi interessa... e con la f(x) unique() chiedo di restituirmi i valori unici della#
#colonna#
# Out:
# array(['NA', 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow',
#        'Grey', 'Silver/Black'], dtype=object)

# %%
#Esercizio 2/3 
#• In media quanto pesano i prodotti?
#• Quanto pesa il più leggero?
#• Quanto pesa il più pesante?
#• Quanti prodotti pesano più di 100 Kg?
#• Quanto costano in media i prodotti (colonna DealerPrice)?
#• Se prendiamo un quarto di tutti i prodotti, in modo che siano i più costosi,
#quale sarà il loro range di prezzo?#

# %%
df['Weight'].describe() # con la semplice descrizione della colonna per parametri statistici usando la f(x)#
#describe ... rispondiamo alle prime 3 domande#
# Out:
# count     282.000000
# mean       56.193227
# std       158.000652
# min         2.120000
# 25%         2.680000
# 50%        15.420000
# 75%        24.130000
# max      1050.000000
# Name: Weight, dtype: float64

# %%
w=df.loc[:,'Weight']>100 #Per conoscere il numero dei prodotti che pesano più di 100 kg. faccio un filtro e lo metto in#
#una variabile w #

# %%
df.loc[w] # in questo modo mi stampo solo le righe dove i prodotti pesano più di 100 kg.
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 179         180             RM-M464                    NaN
# 180         181             RM-M692                    NaN
# 181         182             RM-M823                    NaN
# 182         183             RM-R436                    NaN
# 183         184             RM-R600                    NaN
# 184         185             RM-R800                    NaN
# 185         186             RM-T801                    NaN
# 412         413             FW-R623                   17.0
# 413         414             FW-R762                   17.0
# 414         415             FW-R820                   17.0
# 421         422             RW-R623                   17.0
# 422         423             RW-R762                   17.0
# 423         424             RW-R820                   17.0
# 500         501             RD-2308                    9.0
# 513         514             RB-9231                    6.0
# ...

# %%
w.value_counts() #Ci sono 28 prodotti che pesano più di 100 Kg.#
# Out:
# Weight
# False    578
# True      28
# Name: count, dtype: int64

# %%
df['ListPrice'].describe()#Per prendere il quarto più costoso devo prende della ListPrice il max. quartile#
# Out:
# count     395.000000
# mean      747.661544
# std       838.708359
# min         2.290000
# 25%        69.990000
# 50%       364.090000
# 75%      1204.320000
# max      3578.270000
# Name: ListPrice, dtype: float64

# %%
dp=df.loc[:,'DealerPrice']
dp.describe() #Mi seleziono con .loc la colonna 'DealerPrice' e con describe vedo i dati statistici della colonna#
# Out:
# count     395.000000
# mean      448.597060
# std       503.225071
# min         1.374000
# 25%        41.994000
# 50%       218.454000
# 75%       722.594900
# max      2146.962000
# Name: DealerPrice, dtype: float64

# %%
dp.mean() #Ad ulteriore confema con la f(x) mean mi calcolo la media della colonna che è 448,5970...#
# Out:
# 448.5970597468353

# %%
#Se prendiamo un quarto di tutti i prodotti, in modo che siano i più costosi,
#quale sarà il loro range di prezzo?#

# %%
df['ListPrice'].describe() #Attraverso .describe identifico il3° quartile#
# Out:
# count     395.000000
# mean      747.661544
# std       838.708359
# min         2.290000
# 25%        69.990000
# 50%       364.090000
# 75%      1204.320000
# max      3578.270000
# Name: ListPrice, dtype: float64

# %%
# Mi creo una lista con tutti i valori del 3° quartile cioè quelli > 1.204,32 #
max_quartile = df[df['ListPrice'] > 1204.32]
max_quartile_valori = df[df['ListPrice'] > 1204.32]['ListPrice']
print(max_quartile_valori)
# Out:
# 237    1263.46
# 238    1301.36
# 239    1431.50
# 240    1263.46
# 241    1301.36
#         ...
# 578    1214.85
# 579    1700.99
# 580    1700.99
# 581    1700.99
# 582    1700.99
# Name: ListPrice, Length: 98, dtype: float64

# %%
x=max_quartile_valori
x.describe()  # In tal modo mi individuo il min ed il max del 3° quartile#
# Out:
# count      98.000000
# mean     1954.733265
# std       740.081219
# min      1214.850000
# 25%      1349.600000
# 50%      1700.990000
# 75%      2384.070000
# max      3578.270000
# Name: ListPrice, dtype: float64

# %%
range_prezzi = max(x) - min(x)
print(f'Il minimo è :{min(x)}  Il massimo è:, {max(x)}')
print(f"Il range è: {range_prezzi}")  # Mi calcolo il range tra min e max e poi stampo tutto#
# Out:
# Il minimo è :1214.85  Il massimo è:, 3578.27
# Il range è: 2363.42

# %%
Blue= df.loc[:,'Color']='Blue'

# %%
#Dataset : Amazon collegamento #
#Valutiamo la dimensione del dataset#

# %%
import pandas as pd
import os
print(os.getcwd())
filepath = "C:/Users/Giuseppe/3_PYTHON/FILE_ESERC_CSV/amazon.csv"
amazon = pd.read_csv(filepath)
# Out:
# C:\Users\Giuseppe\3_PYTHON

# %%
amazon = pd.read_csv(filepath)

# %%
amazon
# Out:
#                                               reviewText  Positive
# 0      This is a one of the best apps acording to a b...         1
# 1      This is a pretty good version of the game for ...         1
# 2      this is a really cool game. there are a bunch ...         1
# 3      This is a silly game and can be frustrating, b...         1
# 4      This is a terrific game on any pad. Hrs of fun...         1
# ...                                                  ...       ...
# 19995  this app is fricken stupid.it froze on the kin...         0
# 19996  Please add me!!!!! I need neighbors! Ginger101...         1
# 19997  love it!  this game. is awesome. wish it had m...         1
# 19998  I love love love this app on my side of fashio...         1
# 19999  This game is a rip off. Here is a list of thin...         0
#
# [20000 rows x 2 columns]

# %%
#Valutiamo la dimensione del dataset#

# %%
amazon.shape
# Out:
# (20000, 2)

# %%
# Visualizziamo dieci righe a caso #

# %%
amazon.sample(10)
# Out:
#                                               reviewText  Positive
# 10261  In my house we play this and it's just called ...         1
# 6464   when looking for apps to play on a long car ri...         1
# 2240   If you love Uno you will love this game. It al...         1
# 17921  ........love it........fun.......the bear is a...         1
# 18868  This is the worst app ever. It takes up 1/4 of...         0
# 15828  This is a great app. It never bugs out. Very w...         1
# 863    I had heard about this game and tried to see i...         0
# 5508   Wat an awesome game! I loved on my ipod but no...         1
# 4868   I love this calculator. It is the clearest and...         1
# 15200  Fun when your bored, or with friends. This ver...         1

# %%
#Osserviamo quali sono i nomi di colonna #

# %%
list(amazon.columns)
# Out:
# ['reviewText', 'Positive']

# %%
#Il dataset è bilanciato, ovvero, il numero di recensioni positive è uguale a
#quello delle negative, oppure no?

# %%
pos=(amazon['Positive']==1).sum() #Filtro sulla colonna 'Positive' metto in una variabile e sommo i valori#
neg=(amazon['Positive']==0).sum()

# %%
print(f"Il numero delle recensioni positive sono : {pos} \nIl numero delle recensioni negative sono: {neg}\nIl DataFrame è sbilanciato su recensioni positive")
# Out:
# Il numero delle recensioni positive sono : 15233
# Il numero delle recensioni negative sono: 4767
# Il DataFrame è sbilanciato su recensioni positive

# %%
#Il dataset diabetes.csv raccoglie persone con diabete o meno, e il valore di
#diverse variabili fisiologiche dei pazienti.#

# %%
import pandas as pd
import os
print(os.getcwd())
filepath = "C:/Users/Giuseppe/3_PYTHON/FILE_ESERC_CSV/diabetes.csv"
diab = pd.read_csv(filepath)
# Out:
# C:\Users\Giuseppe\3_PYTHON

# %%
#Osserviamone le dimensioni e un'anteprima di cinque righe;#

# %%
diab.shape
# Out:
# (768, 9)

# %%
diab.head(5)
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
#Prendiamoci un po' di tempo per dare un'occhiata ai metadati delle colonne;#

# %%
list(diab.columns)
# Out:
# ['Number of times pregnant',
#  'Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
#  'Diastolic blood pressure (mm Hg)',
#  'Triceps skin fold thickness (mm)',
#  '2-Hour serum insulin (mu U/ml)',
#  'Body mass index (weight in kg/(height in m)^2)',
#  'Diabetes pedigree function',
#  'Age (years)',
#  'Class variable']

# %%
#Stampiamo dei descrittori statistici del dataset#

# %%
diab.describe()
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# ...

# %%
#Selezioniamo i dati relativi a diverse fasce di età: <20, 20-30, 30-40, 40-50, >50;#

# %%
a=(diab['Age (years)'] <20)

# %%
b= (diab['Age (years)'] >=20) & (diab['Age (years)'] <30)

# %%
c= (diab['Age (years)'] >=30) & (diab['Age (years)'] <40)

# %%
d= (diab['Age (years)'] >=40) & (diab['Age (years)'] <50)

# %%
e= (diab['Age (years)'] >=50)

# %%
diab[b]
# Out:
#      Number of times pregnant  \
# 3                           1
# 6                           3
# 7                          10
# 20                          3
# 23                          9
# ..                        ...
# 753                         0
# 758                         1
# 760                         2
# 764                         2
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 3                                                   89
# 6                                                   78
# 7                                                  115
# 20                                                 126
# 23                                                 119
# ..                                                 ...
# 753                                                181
# 758                                                106
# 760                                                 88
# ...

# %%
m1=(diab.loc[a,'Diastolic blood pressure (mm Hg)']).mean()
m2=(diab.loc[b,'Diastolic blood pressure (mm Hg)']).mean()
m3=(diab.loc[c,'Diastolic blood pressure (mm Hg)']).mean()
m4=(diab.loc[d,'Diastolic blood pressure (mm Hg)']).mean()
m5=(diab.loc[e,'Diastolic blood pressure (mm Hg)']).mean()
print(f"La media della pressione sanguigna per fasce d'età: \n<20      {m1}\n20<=<30  {m2}\n30<=<40  {m3}\n40<=<50  {m4}\n>50      {m5}")
# Out:
# La media della pressione sanguigna per fasce d'età:
# <20      nan
# 20<=<30  65.34848484848484
# 30<=<40  69.66666666666667
# 40<=<50  73.94067796610169
# >50      78.37078651685393

# %%
#Qual è la media della pressione per ogni singolo anno di età?#

# %%
y=diab.groupby('Age (years)')['Diastolic blood pressure (mm Hg)'].mean()

# %%
media_pressione_x_età = [y,'Diastolic blood pressure (mm Hg)']
print(media_pressione_x_età)
# Out:
# [Age (years)
# 21    65.936508
# 22    63.722222
# 23    64.315789
# 24    64.956522
# 25    59.666667
# 26    64.181818
# 27    73.500000
# 28    68.314286
# 29    68.241379
# 30    64.857143
# 31    64.375000
# 32    70.062500
# 33    65.647059
# 34    74.000000
# 35    75.600000
# 36    69.125000
# 37    75.947368
# 38    71.125000
# 39    72.666667
# 40    69.230769
# 41    67.590909
# 42    73.388889
# 43    78.461538
# 44    61.750000
# 45    83.066667
# 46    76.000000
# 47    78.333333
# 48    78.400000
# 49    81.400000
# 50    78.250000
# 51    84.500000
# 52    81.500000
# 53    79.000000
# 54    89.333333
# 55    70.250000
# 56    76.333333
# 57    76.800000
# 58    78.285714
# 59    74.000000
# 60    80.000000
# 61    76.000000
# 62    71.500000
# 63    78.000000
# 64    78.000000
# 65    78.666667
# 66    86.000000
# 67    72.666667
# 68    82.000000
# 69    81.000000
# 70    82.000000
# 72     0.000000
# 81    74.000000
# ...

# %%
filepath = "C:/Users/Giuseppe/3_PYTHON/FILE_ESERC_CSV/insurance.csv" 
insur = pd.read_csv(filepath)   #Ci siamo connessi alla tabella Insurance #

# %%
insur
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insur.shape #Visualizziamone le dimensioni, un'anteprima, e osserviamo i nomi di colonna #
# Out:
# (1338, 7)

# %%
insur.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
insur.loc[:,'region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
a=insur.loc[:,'region']=='southwest'  #Creiamo un filtro per ogni Area geografice #
b=insur.loc[:,'region']=='southeast'
c=insur.loc[:,'region']=='northwest'
d=insur.loc[:,'region']=='northeast'

# %%
a1=(insur.loc[a,'charges']).mean()  #Calcoliamo la media di charges per ogni DataFrame risultante dal filtro #
b1=(insur.loc[b,'charges']).mean()
c1=(insur.loc[c,'charges']).mean()
d1=(insur.loc[d,'charges']).mean()

# %%
print(f"Media Charges per Area Geografica : \nsouthwest  {a1} \nsoutheast  {b1}\nnorthwest  {c1}\nnortheast  {d1}\n")
# Out:
# Media Charges per Area Geografica :
# southwest  12346.937377292308
# southeast  14735.411437609888
# northwest  12417.57537396923
# northeast  13406.384516385804

# %%
insur.groupby('region')['charges'].mean()
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %%
insur.groupby('smoker')['charges'].mean() #Possiamo fare la stessa cosa con il groupby#
# Out:
# smoker
# no      8434.268298
# yes    32050.231832
# Name: charges, dtype: float64

# %%
insur.groupby('sex')['charges'].mean()
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %%
insur['bmi'].describe() #Quali sono i descrittori statistici di bmi?#
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %%
insur['bmi']
# Out:
# 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
#          ...
# 1333    30.970
# 1334    31.920
# 1335    36.850
# 1336    25.800
# 1337    29.070
# Name: bmi, Length: 1338, dtype: float64

# %%
#Quali sono minimo, media e massimo di charges rispetto ai diversi quartili dei valori di bmi?#
#Si poteva anche fare un filtro per ogni quartile e vedere i valori statistici con la funzione .describe sulla colonna 'charges'

# %%
q1_media = insur[insur['bmi'] <= 26.296250]['charges'].mean()
q1_min = insur[insur['bmi'] <= 26.296250]['charges'].min()
q1_max = insur[insur['bmi'] <= 26.296250]['charges'].max()
print(f" 1° quartile BMI :\nmedia   {q1_media}\nminimo  {q1_min}\nmassimo {q1_max}")
# Out:
#  1° quartile BMI :
# media   10360.662825492538
# minimo  1121.8739
# massimo 38245.59327

# %%
q2_media = insur[insur['bmi'] <= 30.400000]['charges'].mean()
q2_min = insur[insur['bmi'] <= 30.40000]['charges'].min()
q2_max = insur[insur['bmi'] <= 30.40000]['charges'].max()
print(f" 2° quartile BMI :\nmedia   {q2_media}\nminimo  {q2_min}\nmassimo {q2_max}")
# Out:
#  2° quartile BMI :
# media   10886.581103445766
# minimo  1121.8739
# massimo 62592.87309

# %%
q3_media = insur[insur['bmi'] <= 34.693750]['charges'].mean()
q3_min = insur[insur['bmi'] <= 34.693750]['charges'].min()
q3_max = insur[insur['bmi'] <= 34.693750]['charges'].max()
print(f" 3° quartile BMI :\nmedia   {q3_media}\nminimo  {q3_min}\nmassimo {q3_max}")
# Out:
#  3° quartile BMI :
# media   12028.77985970987
# minimo  1121.8739
# massimo 62592.87309

# %%
q4_media = insur[insur['bmi'] > 34.693750]['charges'].mean()
q4_min = insur[insur['bmi'] > 34.693750]['charges'].min()
q4_max = insur[insur['bmi'] > 34.693750]['charges'].max()
print(f" 4° quartile BMI :\nmedia   {q4_media}\nminimo  {q4_min}\nmassimo {q4_max}")
# Out:
#  4° quartile BMI :
# media   16987.936690955226
# minimo  1141.4451
# massimo 63770.42801

# %%
filepath = "C:/Users/Giuseppe/3_PYTHON/FILE_ESERC_CSV/pokemon.csv" 
pok = pd.read_csv(filepath)   #Ci siamo connessi alfile csv Pokemon #

# %%
pok
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pok.shape
# Out:
# (800, 13)

# %%
pok.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#È verosimile che la prima colonna dovrebbe essere un indice # I numeri nella colonna '#' sono meno delle 800 righe della tabella #
# per cui o per alcune righe si ripetono i valori o in alcune righe manca il valore ... può assolvere alla funzione di indice ma si dovrebbe#
#capire se ci sono valori che si ripetono e perchè#

# %%
pok=pok.set_index('#')

# %%
pok
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pok.iloc[:,0].value_counts()
# Out:
# Name
# Bulbasaur              1
# Uxie                   1
# GalladeMega Gallade    1
# Probopass              1
# Dusknoir               1
#                       ..
# Lugia                  1
# Ho-oh                  1
# Celebi                 1
# Treecko                1
# Volcanion              1
# Name: count, Length: 800, dtype: int64

# %%
#Quali sono i Pokémon leggendari?#

# %%
Leg=pok[pok['Legendary']==True]

# %%
print(Leg['Name'])
# Out:
# #
# 144               Articuno
# 145                 Zapdos
# 146                Moltres
# 150                 Mewtwo
# 150    MewtwoMega Mewtwo X
#               ...
# 719                Diancie
# 719    DiancieMega Diancie
# 720    HoopaHoopa Confined
# 720     HoopaHoopa Unbound
# 721              Volcanion
# Name: Name, Length: 65, dtype: object

# %%
Typ=pok[pok['Type 1']=='Grass']

# %%
print(Typ['Name'])
# Out:
# #
# 1                  Bulbasaur
# 2                    Ivysaur
# 3                   Venusaur
# 3      VenusaurMega Venusaur
# 43                    Oddish
#                ...
# 650                  Chespin
# 651                Quilladin
# 652               Chesnaught
# 672                   Skiddo
# 673                   Gogoat
# Name: Name, Length: 70, dtype: object

# %%
F2=(pok['Legendary']==True) & (pok['Type 1']=='Grass') #E quali sono i leggendari di tipo 1 Grass?#
pok_F2=pok[F2]
pok_F2
# Out:
#                   Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 492  ShayminLand Forme  Grass       NaN    600  100     100      100      100
# 492   ShayminSky Forme  Grass    Flying    600  100     103       75      120
# 640           Virizion  Grass  Fighting    580   91      90       72       90
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 492      100    100           4       True
# 492       75    127           4       True
# 640      129    108           5       True

# %%
F3=(pok['Legendary']==True) & (pok['Type 1']=='Ice') #E leggendari di tipo 1 Ice ?
pok_F3=pok[F3]
pok_F3
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 144  Articuno    Ice  Flying    580  90      85      100       95      125
# 378    Regice    Ice     NaN    580  80      50      100      100      200
#
#      Speed  Generation  Legendary
# #
# 144     85           1       True
# 378     50           3       True

# %%
F4=(pok['Legendary']==True) & (pok['Type 1']=='Fire') #E leggendari di tipo 1 Fire?
pok_F4=pok[F4]
pok_F4
# Out:
#           Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 146    Moltres   Fire  Flying    580   90     100       90      125       85
# 244      Entei   Fire     NaN    580  115     115       85       90       75
# 250      Ho-oh   Fire  Flying    680  106     130       90      110      154
# 485    Heatran   Fire   Steel    600   91      90      106      130      106
# 721  Volcanion   Fire   Water    600   80     110      120      130       90
#
#      Speed  Generation  Legendary
# #
# 146     90           1       True
# 244    100           2       True
# 250     90           2       True
# 485     77           4       True
# 721     70           6       True

# %%
pok_ord=pok.sort_values(by='Name', ascending=True)  #Ordiniamo il dataset per la colonna Name#
pok_ord
# Out:
#                         Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# #
# 460                Abomasnow    Grass     Ice    494   90      92       75
# 460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132      105
# 63                      Abra  Psychic     NaN    310   25      20       15
# 359                    Absol     Dark     NaN    465   65     130       60
# 359          AbsolMega Absol     Dark     NaN    565   65     150       60
# ..                       ...      ...     ...    ...  ...     ...      ...
# 571                  Zoroark     Dark     NaN    510   60     105       60
# 570                    Zorua     Dark     NaN    330   40      65       40
# 41                     Zubat   Poison  Flying    245   40      45       35
# 634                 Zweilous     Dark  Dragon    420   72      85       70
# 718         Zygarde50% Forme   Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pok_ord=pok_ord.set_index('Name') #Trasformiamo Name nell'indice;#
pok_ord
# Out:
#                           Type 1  Type 2  Total   HP  Attack  Defense  \
# Name
# Abomasnow                  Grass     Ice    494   90      92       75
# AbomasnowMega Abomasnow    Grass     Ice    594   90     132      105
# Abra                     Psychic     NaN    310   25      20       15
# Absol                       Dark     NaN    465   65     130       60
# AbsolMega Absol             Dark     NaN    565   65     150       60
# ...                          ...     ...    ...  ...     ...      ...
# Zoroark                     Dark     NaN    510   60     105       60
# Zorua                       Dark     NaN    330   40      65       40
# Zubat                     Poison  Flying    245   40      45       35
# Zweilous                    Dark  Dragon    420   72      85       70
# Zygarde50% Forme          Dragon  Ground    600  108     100      121
#
#                          Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
F4=(pok['HP']>50) & (pok['HP']<=60) #E leggendari di tipo 1 Ice ?
pok_F4=pok[F4]
pok_F4
# Out:
#                     Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 2                Ivysaur   Grass  Poison    405  60      62       63       80
# 5             Charmeleon    Fire     NaN    405  58      64       58       80
# 8              Wartortle   Water     NaN    405  59      63       80       65
# 12            Butterfree     Bug  Flying    395  60      45       50       90
# 20              Raticate  Normal     NaN    413  55      81       60       50
# ..                   ...     ...     ...    ...  ..     ...      ...      ...
# 707               Klefki   Steel   Fairy    470  57      80       91       80
# 710  PumpkabooLarge Size   Ghost   Grass    335  54      66       70       44
# 710  PumpkabooSuper Size   Ghost   Grass    335  59      66       70       44
# 711  GourgeistSmall Size   Ghost   Grass    494  55      85      122       58
# 712             Bergmite     Ice     NaN    304  55      69       85       32
#
# ...

# %%
pok_F4_ordinato = pok_F4.sort_values(by='HP')  #per una maggiore visibilità si ordina

# %%
pok_F4_ordinato
# Out:
#            Name    Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 583   Vanillish       Ice      NaN    395  51      65       65       80
# 633       Deino      Dark   Dragon    300  52      65       50       45
# 83   Farfetch'd    Normal   Flying    352  52      65       55       58
# 686       Inkay      Dark  Psychic    288  53      54       53       37
# 393      Piplup     Water      NaN    314  53      51       53       61
# ..          ...       ...      ...    ...  ..     ...      ...      ...
# 411   Bastiodon      Rock    Steel    495  60      52      168       47
# 407    Roserade     Grass   Poison    515  60      70       65      125
# 404       Luxio  Electric      NaN    363  60      85       49       60
# 101   Electrode  Electric      NaN    480  60      50       70       80
# 2       Ivysaur     Grass   Poison    405  60      62       63       80
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 583       75     59           5      False
# ...
